# %%
# importing all the important libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the Boston dataset
data=pd.read_csv(r"F:\DSEU ALL SUBJECTS FOLDER AND IMAGES\SEMESTER-2\Machine_learning_Dataset\Boston.csv")
data
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
# Have a glance at the shape
df = pd.DataFrame(data)
shape = df.shape
print(shape)
# Out:
# (506, 15)

# %%
#input
x=data.iloc[:,[2,3]].values
#output
y=data.iloc[:,4].values

# %%
import seaborn as sns
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
#Have a glance at the dependent and independent variables
data_1=data.loc[:,["lstat","medv"]]
data_1.head()
# Out:
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
#  Visualize the change in the variables
data.plot(x="lstat",y="medv",style="o")
plt.xlabel("lstat")
plt.ylabel("medv")
plt.show()

# %%
#Step 5: Divide the data into independent and dependent variables
X=pd.DataFrame(data['lstat'])
Y=pd.DataFrame(data['medv'])
print(X)
print(Y)
print(X.shape)
print(Y.shape)
# Out:
#      lstat
# 0     4.98
# 1     9.14
# 2     4.03
# 3     2.94
# 4     5.33
# ..     ...
# 501   9.67
# 502   9.08
# 503   5.64
# 504   6.48
# 505   7.88
#
# [506 rows x 1 columns]
#      medv
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 1 columns]
# (506, 1)
# (506, 1)

# %%
# Split the data into train and test sets
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=1)

# %%
#  Shape of the train and test sets
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (404, 1)
# (102, 1)
# (404, 1)
# (102, 1)

# %%
from sklearn.preprocessing import StandardScaler
sc_x=StandardScaler()
xtrain=sc_x.fit_transform(X_train)
xtest=sc_x.fit_transform(X_test)
print(xtrain[0:10,:])
# Out:
# [[-0.96685016]
#  [-0.82116789]
#  [ 2.50177533]
#  [-0.06084519]
#  [ 0.60790581]
#  [-1.00986112]
#  [ 0.05153828]
#  [-0.70878443]
#  [-1.33452447]
#  [-0.51870375]]

# %%
# Train the algorithm
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
# Retrieve the intercept
print(regressor.intercept_)
# Out:
# [34.33497839]

# %%
#  Retrieve the slope
print(regressor.coef_)
# Out:
# [[-0.92441715]]

# %%
plt.scatter(X_train,Y_train,color='ORANGE')

# %%
# predicated value
Y_pred= regressor.predict(X_train)
print(Y_pred)
# Out:
# [[28.96411475]
#  [27.99347674]
#  [ 5.853686  ]
#  [22.92767076]
#  [18.4719801 ]
#  [29.25068407]
#  [22.17889287]
#  [27.24469885]
#  [31.4138202 ]
#  [25.97824735]
#  [14.44152132]
#  [28.35399943]
#  [27.13376879]
#  [31.68190117]
#  [25.33115535]
#  [23.52854191]
#  [32.50463243]
#  [27.45731479]
#  [25.1185394 ]
#  [17.03913351]
#  [29.86079938]
#  [21.21749903]
#  [25.54377129]
#  [22.39150881]
#  [26.40347924]
#  [25.94127067]
#  [20.75529046]
#  [29.44481167]
#  [21.25447572]
#  [24.75801672]
#  [28.59434789]
#  [10.59594598]
#  [27.66068657]
#  [27.92876754]
#  [ 9.54211043]
#  [16.76180837]
#  [27.34638474]
#  [18.42575924]
#  [29.18597486]
#  [17.2702378 ]
#  [17.08535437]
#  [28.45568532]
#  [31.25666928]
#  [25.8673173 ]
#  [27.67917491]
#  [14.62640475]
#  [28.18760434]
#  [17.76017889]
#  [25.46981792]
#  [15.95756545]
#  [26.69929273]
#  [20.98639474]
#  [14.70035812]
#  [30.3414963 ]
#  [27.75312828]
#  [27.18923382]
#  [20.78302297]
#  [25.51603878]
# ...

# %%
Y_test
# Out:
#      medv
# 307  28.2
# 343  23.9
# 47   16.6
# 67   22.0
# 362  20.8
# ..    ...
# 92   22.9
# 224  44.8
# 110  21.7
# 426  10.2
# 443  15.4
#
# [102 rows x 1 columns]

# %%
# Evaluate the algorithm
from sklearn import metrics
import numpy as np
print("Mean Absolute Error:",metrics.mean_absolute_error(Y_pred,Y_train))
print("Mean Square Error:", metrics.mean_squared_error(Y_pred,Y_train))
print("Root Mean squared Error:",np.sqrt(metrics.mean_squared_error(Y_pred,Y_train)))
# Out:
# Mean Absolute Error: 4.384375153324861
# Mean Square Error: 36.389745631141025
# Root Mean squared Error: 6.032391369195223
